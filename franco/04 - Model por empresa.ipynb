# %% [markdown]
# # Modelos por empresa
#
# ## Objetivo
#
# Para cada id_empresa en tu dataset:
#
# - Filtrar los datos
# - Dividir en entrenamiento/test (80/20)
# - Entrenar un TabularPredictor
# - Evaluar accuracy, F1, precision, recall
# - Guardar resultados por empresa

# %% [markdown]
# ### Paso 1: Código completo para correr todo el pipeline

# %%
import pandas as pd

# Reemplazá el nombre del archivo por la ruta correcta si no está en el mismo directorio
analisis_df = pd.read_csv("data_set_integrado_modelo_final_futuro_binario.csv")

# Ver features
print(analisis_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2909 entries, 0 to 2908
# Data columns (total 76 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   id_cotizacion                              2909 non-null   int64
#  1   id_empresa                                 2909 non-null   int64
#  2   fecha                                      2909 non-null   object
#  3   precio_apertura                            2909 non-null   float64
#  4   precio_cierre                              2909 non-null   float64
#  5   precio_max                                 2909 non-null   float64
#  6   precio_min                                 2909 non-null   float64
#  7   volumen_operado                            2909 non-null   float64
#  8   variacion_porcentaje                       2862 non-null   float64
#  9   nombre                                     2909 non-null   object
#  10  label                                      2909 non-null   object
#  11  variacion_total_cotizacion                 2909 non-null   float64
#  12  total_noticias_negativas                   2909 non-null   int64
#  13  suma_score_sentimiento_negativas           2909 non-null   float64
#  14  total_noticias_positivas                   2909 non-null   int64
#  15  suma_score_sentimiento_positivas           2900 non-null   float64
#  16  fecha_publicacion                          2846 non-null   object
#  17  valoracion_llm                             2846 non-null   object
#  18  tendencia_precio_5d                        2909 non-null   float64
#  19  anio                                       2909 non-null   int64
#  20  mes                                        2909 non-null   int64
#  21  dia                                        2909 non-null   int64
#  22  dia_semana                                 2909 non-null   int64
#  23  es_fin_de_mes                              2909 non-null   int64
#  24  variacion_porcentaje_lag_1                 2871 non-null   float64
#  25  variacion_porcentaje_lag_2                 2879 non-null   float64
#  26  variacion_porcentaje_lag_3                 2886 non-null   float64
#  27  precio_cierre_lag_1                        2909 non-null   float64
#  28  precio_cierre_lag_2                        2909 non-null   float64
#  29  precio_cierre_lag_3                        2909 non-null   float64
#  30  volumen_operado_lag_1                      2909 non-null   float64
#  31  volumen_operado_lag_2                      2909 non-null   float64
#  32  volumen_operado_lag_3                      2909 non-null   float64
#  33  suma_score_sentimiento_positivas_lag_1     2891 non-null   float64
#  34  suma_score_sentimiento_positivas_lag_2     2882 non-null   float64
#  35  suma_score_sentimiento_positivas_lag_3     2873 non-null   float64
#  36  suma_score_sentimiento_negativas_lag_1     2900 non-null   float64
#  37  suma_score_sentimiento_negativas_lag_2     2891 non-null   float64
#  38  suma_score_sentimiento_negativas_lag_3     2882 non-null   float64
#  39  total_noticias_positivas_lag_1             2909 non-null   float64
#  40  total_noticias_positivas_lag_2             2909 non-null   float64
#  41  total_noticias_positivas_lag_3             2909 non-null   float64
#  42  total_noticias_negativas_lag_1             2909 non-null   float64
#  43  total_noticias_negativas_lag_2             2909 non-null   float64
#  44  total_noticias_negativas_lag_3             2909 non-null   float64
#  45  variacion_porcentaje_media_3d              2844 non-null   float64
#  46  variacion_porcentaje_std_3d                2844 non-null   float64
#  47  variacion_porcentaje_media_5d              2826 non-null   float64
#  48  variacion_porcentaje_std_5d                2826 non-null   float64
#  49  precio_cierre_media_3d                     2909 non-null   float64
#  50  precio_cierre_std_3d                       2909 non-null   float64
#  51  precio_cierre_media_5d                     2909 non-null   float64
#  52  precio_cierre_std_5d                       2909 non-null   float64
#  53  volumen_operado_media_3d                   2909 non-null   float64
#  54  volumen_operado_std_3d                     2909 non-null   float64
#  55  volumen_operado_media_5d                   2909 non-null   float64
#  56  volumen_operado_std_5d                     2909 non-null   float64
#  57  suma_score_sentimiento_positivas_media_3d  2864 non-null   float64
#  58  suma_score_sentimiento_positivas_std_3d    2864 non-null   float64
#  59  suma_score_sentimiento_positivas_media_5d  2828 non-null   float64
#  60  suma_score_sentimiento_positivas_std_5d    2828 non-null   float64
#  61  suma_score_sentimiento_negativas_media_3d  2891 non-null   float64
#  62  suma_score_sentimiento_negativas_std_3d    2891 non-null   float64
#  63  suma_score_sentimiento_negativas_media_5d  2873 non-null   float64
#  64  suma_score_sentimiento_negativas_std_5d    2873 non-null   float64
#  65  total_noticias_positivas_media_3d          2909 non-null   float64
#  66  total_noticias_positivas_std_3d            2909 non-null   float64
#  67  total_noticias_positivas_media_5d          2909 non-null   float64
#  68  total_noticias_positivas_std_5d            2909 non-null   float64
#  69  total_noticias_negativas_media_3d          2909 non-null   float64
#  70  total_noticias_negativas_std_3d            2909 non-null   float64
#  71  total_noticias_negativas_media_5d          2909 non-null   float64
#  72  total_noticias_negativas_std_5d            2909 non-null   float64
#  73  ratio_sent_positivo_negativo               2900 non-null   float64
#  74  diff_score_sentimiento                     2900 non-null   float64
#  75  label_t_plus_1                             2909 non-null   object
# dtypes: float64(61), int64(9), object(6)
# memory usage: 1.7+ MB
# None

# %%
from autogluon.tabular import TabularPredictor
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd

# Asegurarse que fecha esté en formato datetime
analisis_df['fecha'] = pd.to_datetime(analisis_df['fecha'])

# Lista para guardar resultados por empresa
resultados_empresas = []

# Lista única de empresas
empresas = analisis_df['id_empresa'].unique()

# Recorrer cada empresa
for empresa_id in empresas:
    df_empresa = analisis_df[analisis_df['id_empresa'] == empresa_id].copy()
    df_empresa = df_empresa.sort_values('fecha').reset_index(drop=True)
    
    if df_empresa['label_t_plus_1'].nunique() < 2 or len(df_empresa) < 50:
        # Saltar empresas sin suficientes datos o sin ambas clases
        continue

    # Separar en train/test (80/20)
    split_idx = int(len(df_empresa) * 0.8)
    train_df = df_empresa.iloc[:split_idx]
    test_df = df_empresa.iloc[split_idx:]

    excluded_cols = ['label', 'label_t_plus_1', 'nombre', 'fecha', 'fecha_publicacion', 'id_cotizacion']
    feature_cols = [col for col in train_df.columns if col not in excluded_cols]

    # Entrenar modelo
    predictor = TabularPredictor(label='label_t_plus_1', problem_type='binary', verbosity=0).fit(
        train_data=train_df[feature_cols + ['label_t_plus_1']],
        verbosity=0
    )

    # Evaluar
    y_true = test_df['label_t_plus_1']
    y_pred = predictor.predict(test_df[feature_cols])

    resultados_empresas.append({
        'id_empresa': empresa_id,
        'empresa': df_empresa['nombre'].iloc[0],
        'n_muestras': len(df_empresa),
        'accuracy': accuracy_score(y_true, y_pred),
        'precision_sube': precision_score(y_true, y_pred, pos_label='SUBE', zero_division=0),
        'recall_sube': recall_score(y_true, y_pred, pos_label='SUBE', zero_division=0),
        'f1_sube': f1_score(y_true, y_pred, pos_label='SUBE', zero_division=0),
    })
# Out:
# 	Warning: Exception caused NeuralNetTorch to fail during training... Skipping this model.
# 		ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 	Warning: Exception caused NeuralNetTorch to fail during training... Skipping this model.
# 		ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 	Warning: Exception caused NeuralNetTorch to fail during training... Skipping this model.
# 		ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 	Warning: Exception caused NeuralNetTorch to fail during training... Skipping this model.
# 		ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 	Warning: Exception caused NeuralNetTorch to fail during training... Skipping this model.
# 		ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 	Warning: Exception caused NeuralNetTorch to fail during training... Skipping this model.
# 		ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 	Warning: Exception caused NeuralNetTorch to fail during training... Skipping this model.
# 		ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 	Warning: Exception caused NeuralNetTorch to fail during training... Skipping this model.
# 		ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 	Warning: Exception caused NeuralNetTorch to fail during training... Skipping this model.
# 		ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'

# %% [markdown]
# ### Paso 2: Paso final: Ver los resultados ordenados

# %%
# Convertir a DataFrame y ordenar por F1
df_resultados = pd.DataFrame(resultados_empresas)
df_resultados = df_resultados.sort_values(by='f1_sube', ascending=False)

# Mostrar top 10
print("📈 Empresas más predecibles (según F1 para SUBE):")
display(df_resultados.head(10))
# Out:
# 📈 Empresas más predecibles (según F1 para SUBE):
#    id_empresa empresa  n_muestras  accuracy  precision_sube  recall_sube  \
# 8          18    XOMD         324  0.569231        0.435897     0.739130
# 4          14   MSFTD         324  0.384615        0.379310     0.846154
# 3          13   MELID         324  0.492308        0.457143     0.533333
# 7          17   VISTD         324  0.461538        0.372093     0.666667
# 5          15   NVDAD         324  0.492308        0.405405     0.576923
# 6          16    TEND         320  0.531250        0.360000     0.391304
# 1          11   DESPD         321  0.569231        0.400000     0.333333
# 0          10   AAPLD         324  0.446154        0.320000     0.296296
# 2          12     KOD         324  0.476923        0.333333     0.172414
#
#     f1_sube
# 8  0.548387
# 4  0.523810
# 3  0.492308
# 7  0.477612
# 5  0.476190
# 6  0.375000
# 1  0.363636
# 0  0.307692
# 2  0.227273

# %% [markdown]
# ## Uso de optimización con hiperparámetros

# %%
from autogluon.tabular import TabularPredictor
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
import pandas as pd

empresas = analisis_df['id_empresa'].unique()
resultados_empresas = []

for empresa_id in empresas:
    df_empresa = analisis_df[analisis_df['id_empresa'] == empresa_id].copy()
    df_empresa = df_empresa.sort_values('fecha').reset_index(drop=True)

    if df_empresa['label_t_plus_1'].nunique() < 2 or len(df_empresa) < 100:
        continue

    # Train/Test split
    split_idx = int(len(df_empresa) * 0.7)
    train_df = df_empresa.iloc[:split_idx]
    test_df = df_empresa.iloc[split_idx:]

    excluded_cols = ['label', 'label_t_plus_1', 'nombre', 'fecha', 'fecha_publicacion', 'id_cotizacion']
    feature_cols = [col for col in train_df.columns if col not in excluded_cols]

    try:
        # AutoML con tuning de hiperparámetros
        predictor = TabularPredictor(label='label_t_plus_1', problem_type='binary').fit(
            train_data=train_df[feature_cols + ['label_t_plus_1']],
            hyperparameter_tune_kwargs='auto',
            time_limit=1800,  # Limita a 30 minutos por empresa (ajustable)
            verbosity=0
        )

        y_true = test_df['label_t_plus_1']
        y_pred = predictor.predict(test_df[feature_cols])

        resultados_empresas.append({
            'id_empresa': empresa_id,
            'empresa': df_empresa['nombre'].iloc[0],
            'n_muestras': len(df_empresa),
            'accuracy': accuracy_score(y_true, y_pred),
            'precision_sube': precision_score(y_true, y_pred, pos_label='SUBE', zero_division=0),
            'recall_sube': recall_score(y_true, y_pred, pos_label='SUBE', zero_division=0),
            'f1_sube': f1_score(y_true, y_pred, pos_label='SUBE', zero_division=0)
        })

    except Exception as e:
        print(f"❌ Error con empresa {empresa_id}: {e}")

# %% [markdown]
# ## Resultados

# %%
df_resultados = pd.DataFrame(resultados_empresas).sort_values(by='f1_sube', ascending=False)
display(df_resultados.head(10))
# Out:
#    id_empresa empresa  n_muestras  accuracy  precision_sube  recall_sube  \
# 8          18    XOMD         324  0.581633        0.476923     0.815789
# 0          10   AAPLD         324  0.428571        0.419355     0.951220
# 1          11   DESPD         321  0.556701        0.465517     0.692308
# 2          12     KOD         324  0.520408        0.450000     0.658537
# 3          13   MELID         324  0.479592        0.446154     0.659091
# 7          17   VISTD         324  0.459184        0.397059     0.692308
# 6          16    TEND         320  0.437500        0.333333     0.459459
# 4          14   MSFTD         324  0.663265        0.769231     0.250000
# 5          15   NVDAD         324  0.571429        0.000000     0.000000
#
#     f1_sube
# 8  0.601942
# 0  0.582090
# 1  0.556701
# 2  0.534653
# 3  0.532110
# 7  0.504673
# 6  0.386364
# 4  0.377358
# 5  0.000000
